# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
disney=pd.read_html('https://github.com/duncandam86/DataCamp-Projects/blob/master/Disney%20Movies%20and%20Box%20Office%20Success/datasets/disney_movies_total_gross.csv')

# %%
disney=disney[0]

# %%
disney
# Out:
#      Unnamed: 0                      movie_title release_date      genre  \
# 0           NaN  Snow White and the Seven Dwarfs   1937-12-21    Musical
# 1           NaN                        Pinocchio   1940-02-09  Adventure
# 2           NaN                         Fantasia   1940-11-13    Musical
# 3           NaN                Song of the South   1946-11-12  Adventure
# 4           NaN                       Cinderella   1950-02-15      Drama
# ..          ...                              ...          ...        ...
# 574         NaN         The Light Between Oceans   2016-09-02      Drama
# 575         NaN                   Queen of Katwe   2016-09-23      Drama
# 576         NaN                   Doctor Strange   2016-11-04  Adventure
# 577         NaN                            Moana   2016-11-23  Adventure
# 578         NaN     Rogue One: A Star Wars Story   2016-12-16  Adventure
#
#     mpaa_rating  total_gross  inflation_adjusted_gross
# ...

# %%
disney=disney.drop('Unnamed: 0',axis=1)

# %%
disney.head()
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross
# 0    184925485                5228953251
# 1     84300000                2188229052
# 2     83320000                2187090808
# 3     65000000                1078510579
# 4     85000000                 920608730

# %%
disney.columns
# Out:
# Index(['movie_title', 'release_date', 'genre', 'mpaa_rating', 'total_gross',
#        'inflation_adjusted_gross'],
#       dtype='object')

# %%
disney.shape
# Out:
# (579, 6)

# %%
disney.tail()
# Out:
#                       movie_title release_date      genre mpaa_rating  \
# 574      The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                Queen of Katwe   2016-09-23      Drama          PG
# 576                Doctor Strange   2016-11-04  Adventure       PG-13
# 577                         Moana   2016-11-23  Adventure          PG
# 578  Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 574     12545979                  12545979
# 575      8874389                   8874389
# 576    232532923                 232532923
# 577    246082029                 246082029
# 578    529483936                 529483936

# %%
disney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    object
#  1   release_date              579 non-null    object
#  2   genre                     562 non-null    object
#  3   mpaa_rating               523 non-null    object
#  4   total_gross               579 non-null    int64
#  5   inflation_adjusted_gross  579 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 27.3+ KB

# %%
disney.isnull().sum()
# Out:
# movie_title                  0
# release_date                 0
# genre                       17
# mpaa_rating                 56
# total_gross                  0
# inflation_adjusted_gross     0
# dtype: int64

# %%
import missingno as msno

# %%
msno.bar(disney)
# Out:
# <AxesSubplot:>

# %%
disney[disney.genre.isnull()]
# Out:
#                                 movie_title release_date genre mpaa_rating  \
# 20   The Many Adventures of Winnie the Pooh   1977-03-11   NaN         NaN
# 22               Herbie Goes to Monte Carlo   1977-06-24   NaN         NaN
# 23                           The Black Hole   1979-12-21   NaN         NaN
# 24                         Midnight Madness   1980-02-08   NaN         NaN
# 25            The Last Flight of Noah’s Ark   1980-06-25   NaN         NaN
# 26                 The Devil and Max Devlin   1981-01-01   NaN         NaN
# 121                                 Newsies   1992-04-08   NaN          PG
# 122                             Passed Away   1992-04-24   NaN       PG-13
# 128            A Gun in Betty Lou's Handbag   1992-08-21   NaN       PG-13
# 146                          Bound by Honor   1993-04-16   NaN           R
# 155                     My Boyfriend's Back   1993-08-06   NaN       PG-13
# ...

# %%
disney[disney.mpaa_rating.isnull()]
# Out:
#                                 movie_title release_date              genre  \
# 5              20,000 Leagues Under the Sea   1954-12-23          Adventure
# 7                           Sleeping Beauty   1959-01-29              Drama
# 9               The Absent Minded Professor   1961-03-16             Comedy
# 12                   The Sword in the Stone   1963-12-25          Adventure
# 14                       Blackbeard's Ghost   1968-02-08             Comedy
# 16                             The Boatniks   1970-07-01             Comedy
# 17                 Bedknobs and Broomsticks   1971-10-07            Musical
# 18                  The Apple Dumpling Gang   1975-07-01             Comedy
# 19                            Freaky Friday   1977-01-21             Comedy
# 20   The Many Adventures of Winnie the Pooh   1977-03-11                NaN
# 21                             The Rescuers   1977-06-22          Adventure
# ...

# %%
disney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    object
#  1   release_date              579 non-null    object
#  2   genre                     562 non-null    object
#  3   mpaa_rating               523 non-null    object
#  4   total_gross               579 non-null    int64
#  5   inflation_adjusted_gross  579 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 27.3+ KB

# %% [markdown]
# ### PreProcessing

# %%
###changing dtypes of features

# %%
disney['release_date']=pd.to_datetime(disney['release_date'])

# %%
disney[['genre','mpaa_rating']]=disney[['genre','mpaa_rating']].astype('category')  ###because both are categoricall values

# %%
disney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    object
#  1   release_date              579 non-null    datetime64[ns]
#  2   genre                     562 non-null    category
#  3   mpaa_rating               523 non-null    category
#  4   total_gross               579 non-null    int64
#  5   inflation_adjusted_gross  579 non-null    int64
# dtypes: category(2), datetime64[ns](1), int64(2), object(1)
# memory usage: 19.9+ KB

# %%
disney['Year']=disney['release_date'].dt.year.astype('int64')

# %%
disney.head()
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross  Year
# 0    184925485                5228953251  1937
# 1     84300000                2188229052  1940
# 2     83320000                2187090808  1940
# 3     65000000                1078510579  1946
# 4     85000000                 920608730  1950

# %%
disney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    object
#  1   release_date              579 non-null    datetime64[ns]
#  2   genre                     562 non-null    category
#  3   mpaa_rating               523 non-null    category
#  4   total_gross               579 non-null    int64
#  5   inflation_adjusted_gross  579 non-null    int64
#  6   Year                      579 non-null    int64
# dtypes: category(2), datetime64[ns](1), int64(3), object(1)
# memory usage: 24.5+ KB

# %%
disney.tail()
# Out:
#                       movie_title release_date      genre mpaa_rating  \
# 574      The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                Queen of Katwe   2016-09-23      Drama          PG
# 576                Doctor Strange   2016-11-04  Adventure       PG-13
# 577                         Moana   2016-11-23  Adventure          PG
# 578  Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross  Year
# 574     12545979                  12545979  2016
# 575      8874389                   8874389  2016
# 576    232532923                 232532923  2016
# 577    246082029                 246082029  2016
# 578    529483936                 529483936  2016

# %% [markdown]
# ## Data Exploration

# %%
####number of movies in each genre

# %%
disney['genre'].value_counts()
# Out:
# Comedy                 182
# Adventure              129
# Drama                  114
# Action                  40
# Thriller/Suspense       24
# Romantic Comedy         23
# Documentary             16
# Musical                 16
# Western                  7
# Horror                   6
# Black Comedy             3
# Concert/Performance      2
# Name: genre, dtype: int64

# %%
###most commom movie genre

# %%
plt.rcParams['figure.figsize']=[12,8]

# %%
sns.countplot(x='genre',data=disney,order=disney.genre.value_counts().index,palette='magma')
plt.xticks(rotation=90)
plt.show()

# %%
disney[disney.genre=='Black Comedy']
# Out:
#               movie_title release_date         genre mpaa_rating  total_gross  \
# 261   Grosse Pointe Blank   1997-04-11  Black Comedy           R     28084357
# 297              Rushmore   1998-12-11  Black Comedy           R     17105219
# 353  The Royal Tenenbaums   2001-12-14  Black Comedy           R     52353636
#
#      inflation_adjusted_gross  Year
# 261                  51579764  1997
# 297                  28392518  1998
# 353                  76758193  2001

# %%
disney[disney.genre=='Horror']
# Out:
#                          movie_title release_date   genre mpaa_rating  \
# 34   Something Wicked This Way Comes   1983-04-29  Horror         NaN
# 131                   Innocent Blood   1992-09-25  Horror           R
# 190               The Puppet Masters   1994-10-21  Horror           R
# 275    An American Werewolf in Paris   1997-12-25  Horror           R
# 436                       Stay Alive   2006-03-24  Horror       PG-13
# 517                     Fright Night   2011-08-19  Horror           R
#
#      total_gross  inflation_adjusted_gross  Year
# 34       5656087                  15136765  1983
# 131      4877567                   9907922  1992
# 190      8579626                  17727017  1994
# 275     26570463                  48546161  1997
# 436     23086480                  29712825  2006
# 517     18298649                  19452402  2011

# %%
###inflation adjusted by genre

# %%
disney.groupby('genre')['inflation_adjusted_gross'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='genre'>

# %%
###visualize adjuted gross mean by value

# %%
disney.groupby('genre')['inflation_adjusted_gross'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='genre'>

# %%
##stats

# %%
disney.describe()
# Out:
#         total_gross  inflation_adjusted_gross         Year  release_year
# count  5.790000e+02              5.790000e+02   579.000000    579.000000
# mean   6.470179e+07              1.187625e+08  1998.012090   1998.012090
# std    9.301301e+07              2.860853e+08    11.410924     11.410924
# min    0.000000e+00              0.000000e+00  1937.000000   1937.000000
# 25%    1.278886e+07              2.274123e+07  1993.000000   1993.000000
# 50%    3.070245e+07              5.515978e+07  1998.000000   1998.000000
# 75%    7.570903e+07              1.192020e+08  2006.000000   2006.000000
# max    9.366622e+08              5.228953e+09  2016.000000   2016.000000

# %%
##inflation adjusted gros per genre per year

# %%
gen_year=disney.groupby(['genre','release_year']).mean().reset_index()
sns.lineplot(data=gen_year,x='release_year',y='inflation_adjusted_gross',hue='genre')
# Out:
# <AxesSubplot:xlabel='release_year', ylabel='inflation_adjusted_gross'>

# %%
plt.scatter(data=gen_year,x='release_year',y='inflation_adjusted_gross',color='green')

# %%
###in which disney released most number of movies

# %%
disney.release_year.value_counts(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
###MOvies with highest collection
disney.head()
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross  Year  release_year
# 0    184925485                5228953251  1937          1937
# 1     84300000                2188229052  1940          1940
# 2     83320000                2187090808  1940          1940
# 3     65000000                1078510579  1946          1946
# 4     85000000                 920608730  1950          1950

# %%
top_movies=disney.sort_values('inflation_adjusted_gross',ascending=False)
top_movies.head(20)
# Out:
#                               movie_title release_date              genre  \
# 0         Snow White and the Seven Dwarfs   1937-12-21            Musical
# 1                               Pinocchio   1940-02-09          Adventure
# 2                                Fantasia   1940-11-13            Musical
# 8                          101 Dalmatians   1961-01-25             Comedy
# 6                      Lady and the Tramp   1955-06-22              Drama
# 3                       Song of the South   1946-11-12          Adventure
# 564  Star Wars Ep. VII: The Force Awakens   2015-12-18          Adventure
# 4                              Cinderella   1950-02-15              Drama
# 13                        The Jungle Book   1967-10-18            Musical
# 179                         The Lion King   1994-06-15          Adventure
# 524                          The Avengers   2012-05-04             Action
# 441  Pirates of the Caribbean: Dead Man’…   2006-07-07          Adventure
# ...

# %%
disney.iloc[441]
# Out:
# movie_title                 Pirates of the Caribbean: Dead Man’…
# release_date                                 2006-07-07 00:00:00
# genre                                                  Adventure
# mpaa_rating                                                PG-13
# total_gross                                            423315812
# inflation_adjusted_gross                               544817142
# Year                                                        2006
# release_year                                                2006
# Name: 441, dtype: object

# %%
disney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    object
#  1   release_date              579 non-null    datetime64[ns]
#  2   genre                     562 non-null    category
#  3   mpaa_rating               523 non-null    category
#  4   total_gross               579 non-null    int64
#  5   inflation_adjusted_gross  579 non-null    int64
#  6   Year                      579 non-null    int64
#  7   release_year              579 non-null    int64
# dtypes: category(2), datetime64[ns](1), int64(4), object(1)
# memory usage: 29.0+ KB

# %%
###how movie genre impacted earnings

# %%
earnings_genre=disney[['total_gross','inflation_adjusted_gross','genre']].groupby(['genre']).mean().sort_values(by='inflation_adjusted_gross')
display(earnings_genre)
display(earnings_genre.plot(kind='bar'))
# Out:
#                       total_gross  inflation_adjusted_gross
# genre
# Documentary          1.129285e+07              1.271803e+07
# Horror               1.451148e+07              2.341385e+07
# Black Comedy         3.251440e+07              5.224349e+07
# Concert/Performance  5.172823e+07              5.741084e+07
# Drama                3.602608e+07              7.189302e+07
# Western              5.128735e+07              7.381571e+07
# Romantic Comedy      5.009595e+07              7.777708e+07
# Comedy               4.461329e+07              8.466773e+07
# Thriller/Suspense    5.861694e+07              8.965379e+07
# Action               1.046141e+08              1.374734e+08
# Adventure            1.270471e+08              1.903974e+08
# Musical              7.233026e+07              6.035979e+08
# <AxesSubplot:xlabel='genre'>

# %%
sns.stripplot(x='genre',y='inflation_adjusted_gross',data=disney)
plt.xticks(rotation=90)
plt.show()

# %%
disney.columns
# Out:
# Index(['movie_title', 'release_date', 'genre', 'mpaa_rating', 'total_gross',
#        'inflation_adjusted_gross', 'Year', 'release_year'],
#       dtype='object')

# %%
###how ratings impacted earnings

# %%
earnings_rating=disney[['total_gross','inflation_adjusted_gross','mpaa_rating']].groupby(['mpaa_rating']).mean().sort_values(by='inflation_adjusted_gross',ascending=False)
display(earnings_rating)
display(earnings_rating.plot(kind='bar'))
# Out:
#               total_gross  inflation_adjusted_gross
# mpaa_rating
# Not Rated    5.046259e+07              2.998734e+08
# G            9.209061e+07              2.912610e+08
# PG-13        8.118074e+07              1.029486e+08
# PG           7.362521e+07              1.015414e+08
# R            2.936536e+07              5.530581e+07
# <AxesSubplot:xlabel='mpaa_rating'>

# %%
sns.stripplot(x='mpaa_rating',y='inflation_adjusted_gross',data=disney)
plt.xticks(rotation=90)
plt.show()
