# %%
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks")
flatui=['red','blue','green','orange','yellow','violet']
flatui=sns.color_palette(flatui)

# %%
fifa=pd.read_csv('FIFA_data.csv')
pd.set_option('max_column',None)

# %%
fifa.head(10)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
# 9           9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# ...

# %%
fifa.shape
# Out:
# (18206, 89)

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18206 entries, 0 to 18205
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18206 non-null  int64
#  1   ID                        18206 non-null  int64
#  2   Name                      18206 non-null  object
#  3   Age                       18206 non-null  int64
#  4   Photo                     18206 non-null  object
#  5   Nationality               18206 non-null  object
#  6   Flag                      18206 non-null  object
#  7   Overall                   18206 non-null  int64
#  8   Potential                 18206 non-null  int64
#  9   Club                      17965 non-null  object
#  10  Club Logo                 18206 non-null  object
#  11  Value                     18206 non-null  object
#  12  Wage                      18206 non-null  object
# ...

# %%
fifa.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
fifa.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
fifa.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
# ...

# %%
fifa.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18206 entries, 0 to 18205
# Data columns (total 88 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18206 non-null  int64
#  1   Name                      18206 non-null  object
#  2   Age                       18206 non-null  int64
#  3   Photo                     18206 non-null  object
#  4   Nationality               18206 non-null  object
#  5   Flag                      18206 non-null  object
#  6   Overall                   18206 non-null  int64
#  7   Potential                 18206 non-null  int64
#  8   Club                      17965 non-null  object
#  9   Club Logo                 18206 non-null  object
#  10  Value                     18206 non-null  object
#  11  Wage                      18206 non-null  object
#  12  Special                   18206 non-null  int64
# ...

# %%
fifa.isnull().sum()
# Out:
# ID                   0
# Name                 0
# Age                  0
# Photo                0
# Nationality          0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 88, dtype: int64

# %%
import missingno as msno

# %%
tempdf=fifa.iloc[:,15:35]     #to shorten the huge amount of columns
tempdf.shape
# Out:
# (18206, 20)

# %%
msno.bar(tempdf)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(tempdf)
# Out:
# <AxesSubplot:>

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18206 entries, 0 to 18205
# Data columns (total 88 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18206 non-null  int64
#  1   Name                      18206 non-null  object
#  2   Age                       18206 non-null  int64
#  3   Photo                     18206 non-null  object
#  4   Nationality               18206 non-null  object
#  5   Flag                      18206 non-null  object
#  6   Overall                   18206 non-null  int64
#  7   Potential                 18206 non-null  int64
#  8   Club                      17965 non-null  object
#  9   Club Logo                 18206 non-null  object
#  10  Value                     18206 non-null  object
#  11  Wage                      18206 non-null  object
#  12  Special                   18206 non-null  int64
# ...

# %%
msno.heatmap(tempdf)
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(fifa)
# Out:
# <AxesSubplot:>

# %%
### pllottinf the heatmap of the collumns using correlation matrix



f,ax=plt.subplots(figsize=(25,15))
sns.heatmap(fifa.corr(),annot=True,linewidths=0.5,linecolor='red',fmt=' .1f',ax=ax)
plt.show()

# %%
###nationality textsize=nationality pllayer count


from wordcloud import WordCloud

# %%
###plotting the wordcloud for the nationaltiy column

plt.subplots(figsize=(25,15))
wordcloud=WordCloud(
    background_color='white',
    width=1920,
    height=1000
    ).generate(" ".join(fifa.Nationality))

plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('graph.png')
plt.show()

# %% [markdown]
# #### filling missing values

# %%
fifa['Club'].fillna('No Club',inplace=True)
fifa['Position'].fillna('ST',inplace=True)

# %%
fifa.isnull().sum()
# Out:
# ID                   0
# Name                 0
# Age                  0
# Photo                0
# Nationality          0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 88, dtype: int64

# %%
fifa.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
#selecting collumns to input teh missing values with mean



to_input_by_mean=fifa.loc[:,['Crossing','Finishing','HeadingAccuracy','ShortPassing','Volleys','Dribbling',
       'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
       'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
       'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
       'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
       'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
       'GKKicking', 'GKPositioning', 'GKReflexes']]

# %%
###replacing mmmissing values with mean

for i in to_input_by_mean.columns:
    fifa[i].fillna(fifa[i].mean(),inplace=True)

# %%
fifa.Crossing.isnull().sum()
# Out:
# 0

# %%
###these are categorical variable and will be inputed by mode###


fifa.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
to_input_by_mode=fifa.loc[:,['Nationality','International Reputation','Body Type','Height','Weight','Preferred Foot','Jersey Number']]
for i in to_input_by_mode.columns:
    fifa[i].fillna(fifa[i].mode()[0],inplace=True)

# %%
#### the followinf variables are eithere discrete numerical or continuos nnumerical variables so it will be  replaced by median


to_input_by_median=fifa.loc[:,['Weak Foot','Skill Moves']]
for i in to_input_by_median.columns:
    fifa[i].fillna(fifa[i].median(),inplace=True)

# %%
fifa['Skill Moves'].isnull().sum()
# Out:
# 0

# %%
###columns remaining to be filled

fifa.columns[fifa.isna().any()]
# Out:
# Index(['Work Rate', 'Real Face', 'Joined', 'Loaned From',
#        'Contract Valid Until', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Release Clause'],
#       dtype='object')

# %%
fifa.fillna(0,inplace=True)   ###to fill remaining null values with 0

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18206 entries, 0 to 18205
# Data columns (total 88 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18206 non-null  int64
#  1   Name                      18206 non-null  object
#  2   Age                       18206 non-null  int64
#  3   Photo                     18206 non-null  object
#  4   Nationality               18206 non-null  object
#  5   Flag                      18206 non-null  object
#  6   Overall                   18206 non-null  int64
#  7   Potential                 18206 non-null  int64
#  8   Club                      18206 non-null  object
#  9   Club Logo                 18206 non-null  object
#  10  Value                     18206 non-null  object
#  11  Wage                      18206 non-null  object
#  12  Special                   18206 non-null  int64
# ...

# %%
fifa.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
###functions to return the rounded values from different columns###

def defending(fifa):
    return int(round((fifa[['Marking','SlidingTackle','SlidingTackle']].mean()).mean()))

def general(fifa):
    return int(round((fifa[['HeadingAccuracy','Dribbling','Curve','BallControl']].mean()).mean()))


def mental(fifa):
    return int(round((fifa[['Aggression','Interceptions','Positioning','Vision','Composure']].mean()).mean()))


def mobility(fifa):
    return int(round((fifa[['Acceleration','SprintSpeed','Agility','Reactions']].mean()).mean()))



def passing(fifa):
    return int(round((fifa[['Crossing','ShortPassing','LongPassing']].mean()).mean()))

def  power(fifa):
    return int(round((fifa[['Balance','Jumping','Stamina','Strength']].mean()).mean()))

def rating(fifa):
    return int(round((fifa[['Potential','Overall']].mean()).mean()))


def shooting(fifa):
    return int(round((fifa[['Finishing','Volleys','FKAccuracy','ShotPower','LongShots','Penalties']].mean()).mean()))

# %%
##renaming a column

fifa.rename(columns={'Club Logo':'Club_Logo'},inplace=True)

# %%
fifa.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club_Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
###adding these categories to the data


fifa['Defending']=fifa.apply(defending,axis=1)
fifa['General']=fifa.apply(general,axis=1)
fifa['Mental']=fifa.apply(mental,axis=1)
fifa['Passing']=fifa.apply(passing,axis=1)
fifa['Mobility']=fifa.apply(mobility,axis=1)
fifa['Power']=fifa.apply(power,axis=1)
fifa['Rating']=fifa.apply(rating,axis=1)
fifa['Shooting']=fifa.apply(shooting,axis=1)

# %%
players=fifa[['Name','Defending','General','Mental','Passing','Mobility','Power','Rating','Shooting']]
players.head(20)
# Out:
#                  Name  Defending  General  Mental  Passing  Mobility  Power  \
# 0            L. Messi         28       89      71       87        91     74
# 1   Cristiano Ronaldo         25       88      73       81        91     83
# 2           Neymar Jr         31       85      72       80        94     69
# 3              De Gea         14       26      43       39        66     54
# 4        K. De Bruyne         57       79      81       92        81     76
# 5           E. Hazard         26       83      72       84        92     75
# 6           L. Modrić         69       81      80       89        84     77
# 7           L. Suárez         46       85      78       74        84     81
# 8        Sergio Ramos         90       78      77       74        78     82
# 9            J. Oblak         21       14      41       23        64     61
# 10     R. Lewandowski         24       84      75       70        81     81
# ...

# %%
##different positions acquired by players


plt.figure(figsize=(18,8))
plt.style.use('fivethirtyeight')
ax=sns.countplot('Position',data=fifa,palette='dark')
ax.set_xlabel(xlabel='Different positions in football',fontsize=16)
ax.set_ylabel(ylabel='Count of players',fontsize=16)
ax.set_title(label='Comparision of positions and players',fontsize=20)
plt.show()

# %%
###plotting count of players based on their height



plt.figure(figsize=(18,8))
ax=sns.countplot('Height',data=fifa,palette='bone')
ax.set_xlabel(xlabel='Count of players in base of height',fontsize=16)
ax.set_ylabel(ylabel='Height in foot per inch',fontsize=16)
ax.set_title(label='count',fontsize=20)
plt.show()

# %%
###Different workrate of players participatiing in fifa 2019



plt.figure(figsize=(15,7))
plt.style.use('fivethirtyeight')
ax=sns.countplot(x='Work Rate',data=fifa,palette='hls')
ax.set_xlabel(xlabel='Workrate associated with players',fontsize=26)
ax.set_ylabel(ylabel='count of players',fontsize=26)
ax.set_title(label='Different workrate of players participatiing in fifa 2019',fontsize=30)
plt.show()

# %%
fifa.Nationality.unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Armenia', 'Switzerland', 'Norway', 'Czech Republic',
#        'Scotland', 'Ghana', 'Central African Rep.', 'DR Congo',
#        'Ivory Coast', 'Russia', 'Ukraine', 'Iceland', 'Mexico', 'Jamaica',
#        'Albania', 'Venezuela', 'Japan', 'Turkey', 'Ecuador', 'Paraguay',
#        'Mali', 'Nigeria', 'Cameroon', 'Dominican Republic', 'Israel',
#        'Kenya', 'Hungary', 'Republic of Ireland', 'Romania',
#        'United States', 'Cape Verde', 'Australia', 'Peru', 'Togo',
# ...

# %%
some_countries=('England','Germany','Spain','Argentina','France','Brazil','Italy','Columbia')  ###defining a tuple of some countries
data_countries=fifa.loc[fifa['Nationality'].isin(some_countries)&fifa['Overall']]
data_countries.head(20)
# Out:
#         ID             Name  Age  \
# 3   193080           De Gea   27
# 8   155862     Sergio Ramos   32
# 14  215914         N. Kanté   27
# 15  211110        P. Dybala   24
# 16  202126          H. Kane   24
# 17  194765     A. Griezmann   27
# 18  192448    M. ter Stegen   26
# 20  189511  Sergio Busquets   29
# 22  167495         M. Neuer   32
# 23  153079        S. Agüero   30
# 24  138956     G. Chiellini   33
# 42  205600        S. Umtiti   24
# 43  201399        M. Icardi   25
# 45  195864         P. Pogba   25
# 48  192387      C. Immobile   28
# 49  189332       Jordi Alba   29
# 54  152729            Piqué   31
# 79  220834    Marco Asensio   22
# 80  216594         N. Fekir   24
# 81  212831          Alisson   25
#
#                                              Photo Nationality  \
# 3   https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 8   https://cdn.sofifa.org/players/4/19/155862.png       Spain
# ...

# %%
####plotting players according to our own specified nationalities



plt.rcParams['figure.figsize']=(15,7)
ax=sns.barplot(x=data_countries['Nationality'],y=data_countries['Overall'],data=fifa,palette='spring')
ax.set_xlabel(xlabel='countries',fontsize=26)
ax.set_ylabel(ylabel='overall_scores',fontsize=26)
ax.set_title(label='Distribution of overall scores of players from different countries',fontsize=20)
plt.show()

# %%
###finding the number of players of each club


fifa['Club'].value_counts().head(20)
# Out:
# No Club                    241
# FC Barcelona                33
# Burnley                     33
# AS Monaco                   33
# Everton                     33
# TSG 1899 Hoffenheim         33
# Wolverhampton Wanderers     33
# Eintracht Frankfurt         33
# Southampton                 33
# Valencia CF                 33
# Newcastle United            33
# Frosinone                   33
# CD Leganés                  33
# Rayo Vallecano              33
# Cardiff City                33
# Fortuna Düsseldorf          33
# RC Celta                    33
# Empoli                      33
# Atlético Madrid             33
# Arsenal                     33
# Name: Club, dtype: int64

# %%
data=fifa.copy()  ##creating a copy

# %%
##for visualizations


import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
sns.set(style='ticks')

# %%
some_clubs=('FC Barcelona', 'Juventus', 'Paris Saint-Germain',
       'Manchester United', 'Manchester City', 'Chelsea', 'Real Madrid',
       'Atlético Madrid', 'FC Bayern München')
data_clubbs=fifa.loc[fifa['Club'].isin(some_clubs)&fifa['Overall']]

# %%
plt.rcParams['figure.figsize']=(15,7)
ax=sns.boxplot(x=data_clubbs['Club'],y=data_clubbs['Overall'],data=fifa,palette='spring')
ax.set_xlabel(xlabel='some popular clubs',fontsize=26)
ax.set_ylabel(ylabel='overall score',fontsize=26)
ax.set_title(label='Distribution of overall scoresin different popular clubs',fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %%
###finding out the top ten left footed footballers

left=data[data['Preferred Foot']=='Left'][['Name','Age','Club','Nationality']].head(10)

left
# Out:
#             Name  Age               Club Nationality
# 0       L. Messi   31       FC Barcelona   Argentina
# 13   David Silva   32    Manchester City       Spain
# 15     P. Dybala   24           Juventus   Argentina
# 17  A. Griezmann   27    Atlético Madrid      France
# 19   T. Courtois   26        Real Madrid     Belgium
# 24  G. Chiellini   33           Juventus       Italy
# 26      M. Salah   26          Liverpool       Egypt
# 28  J. Rodríguez   26  FC Bayern München    Colombia
# 35       Marcelo   30        Real Madrid      Brazil
# 36       G. Bale   28        Real Madrid       Wales

# %%
###finding out the top ten rigt footed footballers


right=data[data['Preferred Foot']=='Right'][['Name','Age','Club','Nationality']].head(10)

right
# Out:
#                  Name  Age                 Club Nationality
# 1   Cristiano Ronaldo   33             Juventus    Portugal
# 2           Neymar Jr   26  Paris Saint-Germain      Brazil
# 3              De Gea   27    Manchester United       Spain
# 4        K. De Bruyne   27      Manchester City     Belgium
# 5           E. Hazard   27              Chelsea     Belgium
# 6           L. Modrić   32          Real Madrid     Croatia
# 7           L. Suárez   31         FC Barcelona     Uruguay
# 8        Sergio Ramos   32          Real Madrid       Spain
# 9            J. Oblak   25      Atlético Madrid    Slovenia
# 10     R. Lewandowski   29    FC Bayern München      Poland

# %%
##comparring the performance of left footed and right footed players
##ballcontroll vs dribbling

sns.lmplot(x='BallControl',y='Dribbling',data=data,col='Preferred Foot')
plt.show()

# %%
##checking the clubs where players fromm the most number of nations play

data.groupby(['Club'])['Nationality'].nunique().sort_values(ascending=False).head(10)
# Out:
# Club
# No Club                   28
# Brighton & Hove Albion    21
# Fulham                    19
# Udinese                   18
# West Ham United           18
# Empoli                    18
# AS Monaco                 18
# Eintracht Frankfurt       18
# Lazio                     18
# Napoli                    18
# Name: Nationality, dtype: int64

# %%
##checking the clubs where players fromm the least number of nations play

data.groupby(['Club'])['Nationality'].nunique().sort_values(ascending=True).head(10)
# Out:
# Club
# Santos                       1
# Ceará Sporting Club          1
# América FC (Minas Gerais)    1
# Paraná                       1
# Chapecoense                  1
# Padova                       1
# Cittadella                   1
# Sangju Sangmu FC             1
# Ranheim Fotball              1
# CA Osasuna                   1
# Name: Nationality, dtype: int64

# %%
##players with maximum potential and overalla performance



player=str(data.loc[data['Potential'].idxmax()][1])
player1=str(data.loc[data['Overall'].idxmax()][1])
print('Maxipum potential: '+player)
print('Maximum overall performance'+player1)
# Out:
# Maxipum potential: K. Mbappé
# Maximum overall performanceL. Messi

# %%
fifa.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club_Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
#finding the players for each performance criteria

pr_cols=['Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
       'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
       'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
       'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
       'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
       'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',


i=0
while i<len(pr_cols):
    print('best {0} : {1}'.format(pr_cols[i],fifa.loc[fifa[pr_cols[i]].idxmax()][1]))
    i += 1
# Out:
#   File "C:\Users\91974\AppData\Local\Temp/ipykernel_42128/586151995.py", line 11
#     i=0
#      ^
# SyntaxError: invalid syntax

# %%
###plot to shoow th prefeed foot choice of differnet pllayers



f,ax=plt.subplots(figsize=(8,6))

sns.countplot(x='Preferred Foot',hue='Real Face',data=fifa)
plt.show()

# %%
###showing the name of pllayers which occures the most number of times in first 20 name

# %%
plt.subplots(figsize=(25,15))
wordcloud=WordCloud(
    background_color='black',
    width=1920,
    height=1000
    ).generate(" ".join(fifa.Name[0:30]))

plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('players.png')
plt.show()

# %%
fifa.columns

# %%
##checking which clubs has been mentioned the most

plt.subplots(figsize=(25,15))
wordcloud=WordCloud(
    background_color='black',
    width=1920,
    height=1000
    ).generate(" ".join(fifa.Club))

plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('clubs.png')
plt.show()

# %%
###showing the pllayers which mentioned the most(left footed)



plt.subplots(figsize=(25,15))
wordcloud=WordCloud(
    background_color='black',
    width=1920,
    height=1000
    ).generate(" ".join(left.Name))      ##left we alrady defined it left above

plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('lefts.png')
plt.show()

# %%
###showing the pllayers which mentioned the most(right footed)



plt.subplots(figsize=(25,15))
wordcloud=WordCloud(
    background_color='white',
    width=1920,
    height=1000
    ).generate(" ".join(right.Name))      ##left we alrady defined it right above

plt.imshow(wordcloud)
plt.axis('off')
plt.savefig('lefts.png')
plt.show()
